# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import os
import requests
import exchanges.binance as binance
import exchanges.bitfinex as bitfinex
import exchanges.BTCMarkets as BTCMarkets
import exchanges.independentreserve as independentreserve
import exchanges.OKEx as OKEx

symbols = ['BTC','ETH','EOS','XRP']

def getRealtimeData(symbol):
    price_list =[]
    binance_depth = binance.getUSDPrice(symbol)
    price_list.append(binance_depth)
    bitfinex_depth = bitfinex.getUSDPrice(symbol)
    price_list.append(bitfinex_depth)
    BTCMarkets_depth = BTCMarkets.getUSDPrice(symbol)
    price_list.append(BTCMarkets_depth)
    independentreserve_depth = independentreserve.getUSDPrice(symbol)
    price_list.append(independentreserve_depth)
    OKEx_depth = OKEx.getUSDPrice(symbol)
    price_list.append(OKEx_depth)
    df = pd.DataFrame(price_list)
    df.columns=['BestBid','BestAsk','Last Trade Price']
    #df['Source'] = ['Binance','Bitfinex','BTCMarket','Independent reserve','OKEx']
    df.insert(0, 'Source', ['Binance','Bitfinex','BTCMarket','Independent reserve','OKEx'])
    return df
    



# df = pd.read_csv(
#     'https://gist.githubusercontent.com/chriddyp/'
#     'c78bf172206ce24f77d6363a2d754b59/raw/'
#     'c353e8ef842413cae56ae3920b8fd78468aa4cb2/'
#     'usa-agricultural-exports-2011.csv')


def generate_table(dataframe, max_rows=10):
    return html.Table(
        # Header
        [html.Tr([html.Th(col) for col in dataframe.columns])] +

        # Body
        [html.Tr([
            html.Td(dataframe.iloc[i][col]) for col in dataframe.columns
        ]) for i in range(min(len(dataframe), max_rows))]
    )


external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)


app.layout = html.Div(
    [  
        html.Div(
            [
                html.Label('Symbol'),
                dcc.Dropdown(
                    id='symbol',
                    options=[
                        {'label': symbol, 'value': symbol} for symbol in symbols
                    ],value='MTL'),
             ],style={'width': '20%', 'display': 'inline-block'}),
    
    
        html.Div(children=
            [
                html.H4(children='Coins comparison on various crypto exchanges'),
                generate_table(df)
            ])
    ]
)

@app.callback(
    dash.dependencies.Output('table', 'children'),
    [dash.dependencies.Input('symbol', 'value')])
def callback_a(dropdown_value):
    return 



if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Dec/2018 14:03:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Dec/2018 14:03:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Dec/2018 14:03:39] "GET /_dash-dependencies HTTP/1.1" 200 -

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import os
import requests
import json
import exchanges.binance as binance
import exchanges.bitfinex as bitfinex
import exchanges.BTCMarkets as BTCMarkets
import exchanges.independentreserve as independentreserve
import exchanges.OKEx as OKEx

symbols = ['BTC','ETH','EOS','XRP']

symbol = 'ETH'
price_list =[]
binance_depth = binance.getUSDPrice(symbol)
print (binance_depth)
price_list.append(binance_depth)

bitfinex_depth = bitfinex.getUSDPrice(symbol)
price_list.append(bitfinex_depth)

BTCMarkets_depth = BTCMarkets.getUSDPrice(symbol)
price_list.append(BTCMarkets_depth)

independentreserve_depth = independentreserve.getUSDPrice(symbol)
price_list.append(independentreserve_depth)

OKEx_depth = OKEx.getUSDPrice(symbol)
price_list.append(OKEx_depth)



print(price_list)

df = pd.DataFrame(price_list)
df.columns=['BestBid','BestAsk','Last Trade Price']
#df['Source'] = ['Binance','Bitfinex','BTCMarket','Independent reserve','OKEx']
df.insert(0, 'Source', ['Binance','Bitfinex','BTCMarket','Independent reserve','OKEx'])

print (df)
# Out:
# ETHBTC
# {'bid': 93.3208, 'ask': 93.3805, 'trade': 93.3454}
# ethusd
# ETH
# eth
# eth
# ETH-USDT
# [{'bid': 93.3208, 'ask': 93.3805, 'trade': 93.3454}, {'bid': '96.596', 'ask': '96.61', 'trade': '96.552'}, {'bid': 93.5242, 'ask': 94.0276, 'trade': 93.5961}, {'bid': 92.78, 'ask': 93.77, 'trade': 93.27}, {'bid': '93.443', 'ask': '93.445', 'trade': '93.443'}]
#                 Source  BestBid  BestAsk Last Trade Price
# 0              Binance  93.3805  93.3208          93.3454
# 1             Bitfinex    96.61   96.596           96.552
# 2            BTCMarket  94.0276  93.5242          93.5961
# 3  Independent reserve    93.77    92.78            93.27
# 4                 OKEx   93.445   93.443           93.443
